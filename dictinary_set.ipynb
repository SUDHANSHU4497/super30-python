# %%
# what is dictinary

# %%
student={
    "name":"John",
    "age":20,
    "city":"New York",
    "course":"Python Programming"}

# %%
employee={
    "name":"Alice", 
    "age":30, 
    "city":"Los Angeles", 
    "department":"HR", 
    "employee_id":12345, 
    "salary":50000, 
    "is_manager":True, 
    "skills":["communication", "leadership", "problem-solving"], 
    "projects":[{"name":"Project A", "deadline":"2023-12-31"}, {"name":"Project B", "deadline":"2024-06-30"}], 
    "performance":{"2022":{"rating":4.5, "bonus":5000}, "2023":{"rating":4.8, "bonus":8000}}}

# %%
employee["name"]
# Out:
# 'Alice'

# %%
employee["projects"]
# Out:
# [{'name': 'Project A', 'deadline': '2023-12-31'},
#  {'name': 'Project B', 'deadline': '2024-06-30'}]

# %%
employee["projects"][1]
# Out:
# {'name': 'Project B', 'deadline': '2024-06-30'}

# %%
employee["projects"][1]['deadline']
# Out:
# '2024-06-30'

# %%
set

# %%
skills = {"Python", "Java", "C++", "JavaScript", 'SQL', 'PYTHON', 'Python', 'NLP', 'ML', 'AI',"python", "Java", "C++"}

# %%
print(skills)
# Out:
# {'AI', 'JavaScript', 'SQL', 'Java', 'PYTHON', 'NLP', 'ML', 'python', 'C++', 'Python'}

# %%
skills = {"Python", "Java", "C++", "JavaScript", "Java"}
cities = {"New York", "Los Angeles", "Chicago", "Houston", "Chicago", "Houston"}
techniques = {"Machine Learning", "Deep Learning", "Natural Language Processing", "Computer Vision"}

# %%
print(skills)
print(cities)
print(techniques)
# Out:
# {'JavaScript', 'Java', 'Python', 'C++'}
# {'Houston', 'Los Angeles', 'Chicago', 'New York'}
# {'Deep Learning', 'Computer Vision', 'Machine Learning', 'Natural Language Processing'}

# %%
print(skills, cities, techniques, sep="\n")
# Out:
# {'JavaScript', 'Java', 'Python', 'C++'}
# {'Houston', 'Los Angeles', 'Chicago', 'New York'}
# {'Deep Learning', 'Computer Vision', 'Machine Learning', 'Natural Language Processing'}

# %%
# dictionary
student = {
    "name": "John",
    "age": 20,
    "course": "super30",
    "city": "bangalore",
}

type(student)
# Out:
# dict

# %%
print(student)
# Out:
# {'name': 'John', 'age': 20, 'course': 'super30', 'city': 'bangalore'}

# %%
skills={"Python", "Git", "SQL", "AI", "ML", "DL", "NLP"}
print(type(skills))
print(skills)
# Out:
# <class 'set'>
# {'SQL', 'AI', 'ML', 'NLP', 'Git', 'Python', 'DL'}
