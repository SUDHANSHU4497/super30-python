# %% [markdown]
# 5 types of datatypes
# int
# float
# str
# bool
# Complex
# NoneType

# %%
type(5.2)
# Out:
# float

# %%
type('5')
# Out:
# str

# %%
type("5")
# Out:
# str

# %%
type("rue")
# Out:
# str

# %%
type(5+2j) #j=sqrt(-1)
# Out:
# complex

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# Operators in python
# 1. +,-, *
# 2. /
# 3. //
# 4. %
# 5. **
# 6. Division By 0

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(2+3)
# Out:
# 5

# %%
print(2*3)
# Out:
# 6

# %%
print("Hello"+"World")
# Out:
# HelloWorld

# %%
print("Hello"*3)
# Out:
# HelloHelloHello

# %%
print(True+True) # true=1, false=0
# Out:
# 2

# %%
print(True*False) # true=1, false=0
# Out:
# 0

# %%
print((3+4j)+(5+6j))
# Out:
# (8+10j)

# %%
print(3/5)
# Out:
# 0.6

# %%
print("Hello" / "World")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print("Hello" / "World")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
print(True / True)
# Out:
# 1.0

# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
print(2**3)
# Out:
# 8

# %%
print(2^3)
# Out:
# 1

# %%
=: assignment operator
!=: not equal to operator
==: comparison operator

# %% [markdown]
# Variable

# %%
age=20

# %%
print(age+10)
# Out:
# 30

# %%
age myself=20, -,@$

# %%
a=10
b=20
c=30

# %%
a,b,c=10,20,30

# %%
d=input("Enter a number: ")
print(d)
# Out:
# 2

# %%
type(d)
# Out:
# str

# %%
int, float, str, bool, complex

# %%
d=int(
    
)
print(d)
print(type(d))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 d=int(input("Enter a your name: "))
#       2 print(d)
#       3 print(type(d))
#
# ValueError: invalid literal for int() with base 10: 'ram'

# %%
name='ram'
type(name)
# Out:
# str

# %%
age=20
type(age)
# Out:
# int

# %%
city="Bangalore"
type(city)
# Out:
# str

# %%
course="Python"
type(course)
# Out:
# str

# %%
experience=2.5
type(experience)
# Out:
# float

# %%
graduation_year=2020
type(graduation_year)
# Out:
# int

# %%
height=5.9
type(height)
# Out:
# float

# %%
is_student=True
type(is_student)
# Out:
# bool

# %%
learning_goal="Become a Data Scientist"
type(learning_goal)
# Out:
# str

# %%
favourable_food="Pizza"
type(favourable_food)
# Out:
# str

# %%
percentage=85.5
type(percentage)
# Out:
# float

# %%
phone_number=1234567890
type(phone_number)
# Out:
# int

# %%
s="hello"
print(s.isalpha())
# Out:
# True

# %%
s="hello"
print(s.isalnum())
# Out:
# True

# %% [markdown]
# string

# %%
s="Hello world"

# %%
# slicing
print(s[0:5])
print(s[0])
print(s[-1])
# Out:
# Hello
# H
# d

# %%
print(s[0:5:3])
# Out:
# Hl

# %%
print(s[-1:--5:1])

# %%
d=s[:]
print(d)
# Out:
# Hello world

# %% [markdown]
# list

# %%
lst=[1, True, 'Ram', 4.0, 5+6j]

# %%
lst[0]=10
print(lst)
# Out:
# [10, 2, 3, 4, 5]

# %%
print(lst[0])
# Out:
# 1

# %%
print(lst[1])
# Out:
# True

# %%
print(lst[2][0])
# Out:
# R

# %%
lst=[1,2,3,4,5]

# %%
print(lst[1:4])
# Out:
# [2, 3, 4]

# %%
print(lst[0:4:2])
# Out:
# [1, 3]

# %% [markdown]
# tuple

# %%
t=(1,2,3,4,5)
id(t)
# Out:
# 2182743982432

# %%
t[0]='ram'
print(t)
id(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 t[0]='ram'
#       2 print(t)
#       3 id(t)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# set

# %%
s={1, 3,5.0, 'ram'}
type(s)
# Out:
# set

# %%
lst=[2,t,5,6,5,5,5,6,3,4,5,6,8,9,0,1]

# %%
p=set(lst)
print(p)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 8, 9, (1, 2, 3, 4, 5)}

# %% [markdown]
# dictionary

# %%
dic={'name': 'ram', 'age': 25, 'city': 'delhi'}

# %%
print(dic['name'])
# Out:
# ram

# %%
dic['name']='shyam'
print(dic)
# Out:
# {'name': 'shyam', 'age': 25, 'city': 'delhi'}

# %%
name='Priya sharma'
batch_name='Super30'
learning_hour_per_day=3

# %%
#list(ordered and mutable)
learning_topics=['Python', 'AI Engineering', 'Machine Learning', 'Deep Learning', 'NLP']

learning_topics.append('SQL')

print(learning_topics)
# Out:
# ['Python', 'AI Engineering', 'Machine Learning', 'Deep Learning', 'NLP', 'SQL']

# %%
#TUPLE(ordered and immutable)
location=('Bangalore', 'Delhi', 'Mumbai', 'Chennai')

# %%
#dict (key-value pairs)
student_info={'name': 'Priya sharma', 'batch': 'Super30', 'learning_hours': 3, "goal": 'Become a Data Scientist'}
print(student_info)
# Out:
# {'name': 'Priya sharma', 'batch': 'Super30', 'learning_hours': 3, 'goal': 'Become a Data Scientist'}

# %%
#dict (key-value pairs)
student_info_2={'name': name, 'batch': batch_name, 'learning_hours': learning_hour_per_day, "goal": 'Become a Data Scientist'}
print(student_info_2)
# Out:
# {'name': 'Priya sharma', 'batch': 'Super30', 'learning_hours': 3, 'goal': 'Become a Data Scientist'}

# %%
print(student_info_2['name'])
# Out:
# Priya sharma

# %%
student_info_2['name']='Priyanka Sharma'

# %%
print(student_info_2['name'])
# Out:
# Priyanka Sharma

# %%
student_info_2['mentor']='Ramesh'

# %%
print(student_info_2)
# Out:
# {'name': 'Priyanka Sharma', 'batch': 'Super30', 'learning_hours': 3, 'goal': 'Become a Data Scientist', 'mentor': 'Ramesh'}

# %%
#set (unordered and mutable)
unique_skills={'Python', 'Machine Learning', 'Deep Learning', 'NLP', 'SQL', 'Python', 'Machine Learning'}
unique_skills.add('Problem Solving')

print(unique_skills)
# Out:
# {'Problem Solving', 'Python', 'NLP', 'Machine Learning', 'SQL', 'Deep Learning'}

# %%
# queue (fifo) - first in first out
task_queue=['watch youtube videos', 'solve coding problems', 'push the code to github']

task_queue.append('find next topic')

print(task_queue)
# Out:
# ['watch youtube videos', 'solve coding problems', 'push the code to github', 'find next topic']

# %%
name='sudhanshu' #"Sudhanshu"

# %%
city='New Delhi'

# %%
profession='Software Engineer'

# %%
experience="3.5 years"

type(experience)
# Out:
# str

# %%
education='B.Tech- computer Science'

# %%
course='AI Engineering'

# %%
interests=['coding', 'reading']

# %%
goal= 'to become ai enggineer'

# %%
hobbies=['traveling', 'music']

# %%
language='English'

# %%
print(name)
print(city)
print(profession)
print(experience)
print(education)
print(course)
print(goal)
print(interests)
print(hobbies)
print(language)
# Out:
# sudhanshu
# New Delhi
# Software Engineer
# 3.5 years
# B.Tech- computer Science
# AI Engineering
# to become ai enggineer
# ['coding', 'reading', 'traveling', 'music']
# ['traveling', 'music']
# English

# %%
print("name:", name)
print("city:", city)
print("profession:", profession)
print("experience:", experience)
print("education:", education)
print("course:", course)
print("goal:", goal)
print("interests:", interests)
print("hobbies:", hobbies)
print("language:", language)
# Out:
# name: sudhanshu
# city: New Delhi
# profession: Software Engineer
# experience: 3.5 years
# education: B.Tech- computer Science
# course: AI Engineering
# goal: to become ai enggineer
# interests: ['coding', 'reading', 'traveling', 'music']
# hobbies: ['traveling', 'music']
# language: English

# %%
print(name, city, profession, experience, education, course, goal, interests, hobbies, language, sep=", ")
# Out:
# sudhanshu, New Delhi, Software Engineer, 3.5 years, B.Tech- computer Science, AI Engineering, to become ai enggineer, ['coding', 'reading', 'traveling', 'music'], ['traveling', 'music'], English

# %%
print(name, city, profession, experience, education, course, goal, interests, hobbies, language, sep="\n ")
# Out:
# sudhanshu
#  New Delhi
#  Software Engineer
#  3.5 years
#  B.Tech- computer Science
#  AI Engineering
#  to become ai enggineer
#  ['coding', 'reading', 'traveling', 'music']
#  ['traveling', 'music']
#  English
